# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, recall_score, precision_score
from sklearn.metrics import precision_recall_fscore_support
import tensorflow as tf
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Input, Dense, Activation,Dropout

# %%
df_data=pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')
df_data
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS           NObeyesdad
# 0             no  Public_Transportation        Normal_Weight
# 1      Sometimes  Public_Transportation        Normal_Weight
# 2     Frequently  Public_Transportation        Normal_Weight
# 3     Frequently                Walking   Overweight_Level_I
# 4      Sometimes  Public_Transportation  Overweight_Level_II
# ...          ...                    ...                  ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III
# 2107   Sometimes  Public_Transportation     Obesity_Type_III
# 2108   Sometimes  Public_Transportation     Obesity_Type_III
# 2109   Sometimes  Public_Transportation     Obesity_Type_III
# 2110   Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
#df_data['NObeyesdad'].value_counts()

# %%
# df_x
df_data.loc()[df_data['family_history_with_overweight']=='no','family_history_with_overweight']=0
df_data.loc()[df_data['family_history_with_overweight']=='yes','family_history_with_overweight']=1

df_data.loc()[df_data['FAVC']=='no','FAVC']=0
df_data.loc()[df_data['FAVC']=='yes','FAVC']=1

df_data.loc()[df_data['SMOKE']=='no','SMOKE']=0
df_data.loc()[df_data['SMOKE']=='yes','SMOKE']=1

df_data.loc()[df_data['SCC']=='no','SCC']=0
df_data.loc()[df_data['SCC']=='yes','SCC']=1

df_data.loc()[df_data['CAEC']=='No','CAEC']=1
df_data.loc()[df_data['CAEC']=='no','CAEC']=1
df_data.loc()[df_data['CAEC']=='Sometimes','CAEC']=2
df_data.loc()[df_data['CAEC']=='Frequently','CAEC']=3
df_data.loc()[df_data['CAEC']=='Always','CAEC']=4

df_data.loc()[df_data['CALC']=='no','CALC']=1
df_data.loc()[df_data['CALC']=='Sometimes','CALC']=2
df_data.loc()[df_data['CALC']=='Frequently','CALC']=3
df_data.loc()[df_data['CALC']=='Always','CALC']=4

df_data.loc()[df_data['Gender']=='Female','Gender']=0
df_data.loc()[df_data['Gender']=='Male','Gender']=1
df_data
df_data.loc()[df_data['MTRANS']=='Public_Transportation','MTRANS']=0
df_data.loc()[df_data['MTRANS']=='Walking','MTRANS']=1

df_data.loc()[df_data['NObeyesdad']=='Normal_Weight','NObeyesdad']=0
df_data.loc()[df_data['NObeyesdad']=='Obesity_Type_I','NObeyesdad']=1
df_data.loc()[df_data['NObeyesdad']=='Obesity_Type_II','NObeyesdad']=2

df_data.loc()[df_data['NObeyesdad']=='Obesity_Type_III','NObeyesdad']=3

df_data.loc()[df_data['NObeyesdad']=='Overweight_Level_I','NObeyesdad']=4
df_data.loc()[df_data['NObeyesdad']=='Overweight_Level_II','NObeyesdad']=5
df_data.loc()[df_data['NObeyesdad']=='Insufficient_Weight','NObeyesdad']=6

# %%
df_data
# Out:
#      Gender        Age    Height      Weight family_history_with_overweight  \
# 0         0  21.000000  1.620000   64.000000                              1
# 1         0  21.000000  1.520000   56.000000                              1
# 2         1  23.000000  1.800000   77.000000                              1
# 3         1  27.000000  1.800000   87.000000                              0
# 4         1  22.000000  1.780000   89.800000                              0
# ...     ...        ...       ...         ...                            ...
# 2106      0  20.976842  1.710730  131.408528                              1
# 2107      0  21.982942  1.748584  133.742943                              1
# 2108      0  22.524036  1.752206  133.689352                              1
# 2109      0  24.361936  1.739450  133.346641                              1
# 2110      0  23.664709  1.738836  133.472641                              1
#
#      FAVC  FCVC  NCP CAEC SMOKE      CH2O SCC       FAF       TUE CALC MTRANS  \
# 0       0   2.0  3.0    2     0  2.000000   0  0.000000  1.000000    1      0
# 1       0   3.0  3.0    2     1  3.000000   1  3.000000  0.000000    2      0
# 2       0   2.0  3.0    2     0  2.000000   0  2.000000  1.000000    3      0
# 3       0   3.0  3.0    2     0  2.000000   0  2.000000  0.000000    3      1
# 4       0   2.0  1.0    2     0  2.000000   0  0.000000  0.000000    2      0
# ...   ...   ...  ...  ...   ...       ...  ..       ...       ...  ...    ...
# 2106    1   3.0  3.0    2     0  1.728139   0  1.676269  0.906247    2      0
# 2107    1   3.0  3.0    2     0  2.005130   0  1.341390  0.599270    2      0
# 2108    1   3.0  3.0    2     0  2.054193   0  1.414209  0.646288    2      0
# 2109    1   3.0  3.0    2     0  2.852339   0  1.139107  0.586035    2      0
# 2110    1   3.0  3.0    2     0  2.863513   0  1.026452  0.714137    2      0
#
#      NObeyesdad
# 0             0
# 1             0
# 2             0
# 3             4
# 4             5
# ...         ...
# 2106          3
# 2107          3
# 2108          3
# 2109          3
# 2110          3
#
# [2111 rows x 17 columns]

# %%
df_data[['family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC','CALC']]=df_x[
    ['family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC','CALC']
].astype(int)

# %%
df_x=df_data.drop(['NObeyesdad'],axis=1)
df_y=df_data.loc[:,'NObeyesdad']

# %%
#資料前處理

# %%
input_layer = Input(shape=(x_train.shape[1],))
dense_layer_1 =Dense(32,kernel_initializer=tf.keras.initializers.GlorotNormal() ,activation='relu', name ="nl1" )(input_layer)
dense_layer_2 = Dense(16,kernel_initializer=tf.keras.initializers.GlorotNormal(),activation='relu', name ="nl2" )(dense_layer_1)
dense_layer_2 = Dense(10,activation='relu', name ="nl3" )(dense_layer_2)
dense_layer_2 = Dense(10,activation='relu', name ="nl4" )(dense_layer_2)
dense_layer_2 = Dropout(0.5)(dense_layer_2)
output = Dense(y_train.shape[1],activation='softmax')(dense_layer_2)
model = Model(inputs=input_layer, outputs=output)
print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 21)]              0
# _________________________________________________________________
# nl1 (Dense)                  (None, 32)                704
# _________________________________________________________________
# nl2 (Dense)                  (None, 16)                528
# _________________________________________________________________
# nl3 (Dense)                  (None, 10)                170
# _________________________________________________________________
# nl4 (Dense)                  (None, 10)                110
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 77
# =================================================================
# Total params: 1,589
# Trainable params: 1,589
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss',mode='min', patience=5)
Adam = tf.optimizers.Adam(lr=0.003, beta_1=0.9, beta_2=0.997, epsilon=1e-08, decay=0.0)
model.compile(optimizer=Adam, 
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics = [tf.keras.metrics.Precision(),tf.keras.metrics.Recall()]
              )
history = model.fit(x=x_train, y=y_train,  epochs=50,batch_size =5, callbacks=[callback] )
# Out:
# Epoch 1/50
# 338/338 [==============================] - 1s 726us/step - loss: 2.2055 - precision_2: 0.1887 - recall_2: 0.0117
# Epoch 2/50
# 338/338 [==============================] - 0s 497us/step - loss: 1.7403 - precision_2: 0.6967 - recall_2: 0.0245
# Epoch 3/50
# 338/338 [==============================] - 0s 488us/step - loss: 1.5203 - precision_2: 0.6539 - recall_2: 0.0888
# Epoch 4/50
# 338/338 [==============================] - 0s 488us/step - loss: 1.3700 - precision_2: 0.6698 - recall_2: 0.1352
# Epoch 5/50
# 338/338 [==============================] - 0s 512us/step - loss: 1.3017 - precision_2: 0.6104 - recall_2: 0.1275
# Epoch 6/50
# 338/338 [==============================] - 0s 509us/step - loss: 1.1745 - precision_2: 0.7235 - recall_2: 0.1855
# Epoch 7/50
# 338/338 [==============================] - 0s 516us/step - loss: 1.1790 - precision_2: 0.7063 - recall_2: 0.1902
# Epoch 8/50
# 338/338 [==============================] - 0s 493us/step - loss: 1.1280 - precision_2: 0.7082 - recall_2: 0.2124
# Epoch 9/50
# 338/338 [==============================] - 0s 497us/step - loss: 1.0882 - precision_2: 0.7218 - recall_2: 0.2386
# Epoch 10/50
# 338/338 [==============================] - 0s 488us/step - loss: 1.1725 - precision_2: 0.7244 - recall_2: 0.2378
# Epoch 11/50
# 338/338 [==============================] - 0s 491us/step - loss: 1.0241 - precision_2: 0.7676 - recall_2: 0.2855
# Epoch 12/50
# 338/338 [==============================] - 0s 491us/step - loss: 0.9831 - precision_2: 0.8070 - recall_2: 0.3212
# Epoch 13/50
# 338/338 [==============================] - 0s 500us/step - loss: 1.0374 - precision_2: 0.7696 - recall_2: 0.2979
# Epoch 14/50
# 338/338 [==============================] - 0s 697us/step - loss: 1.0023 - precision_2: 0.7515 - recall_2: 0.3704
# Epoch 15/50
# 338/338 [==============================] - 0s 518us/step - loss: 1.0034 - precision_2: 0.7524 - recall_2: 0.3193
# Epoch 16/50
# 338/338 [==============================] - 0s 528us/step - loss: 0.9911 - precision_2: 0.7827 - recall_2: 0.3564
# Epoch 17/50
# 338/338 [==============================] - 0s 636us/step - loss: 0.9929 - precision_2: 0.8063 - recall_2: 0.3638
# Epoch 18/50
# 338/338 [==============================] - 0s 574us/step - loss: 0.9716 - precision_2: 0.7809 - recall_2: 0.3798
# Epoch 19/50
# 338/338 [==============================] - 0s 598us/step - loss: 0.9587 - precision_2: 0.7408 - recall_2: 0.3860
# Epoch 20/50
# 338/338 [==============================] - 0s 586us/step - loss: 0.9657 - precision_2: 0.7745 - recall_2: 0.3752
# Epoch 21/50
# 338/338 [==============================] - 0s 512us/step - loss: 0.8858 - precision_2: 0.7819 - recall_2: 0.4160
# Epoch 22/50
# 338/338 [==============================] - 0s 507us/step - loss: 0.8729 - precision_2: 0.7691 - recall_2: 0.4315
# Epoch 23/50
# 338/338 [==============================] - 0s 521us/step - loss: 1.0011 - precision_2: 0.7543 - recall_2: 0.3723
# Epoch 24/50
# 338/338 [==============================] - 0s 526us/step - loss: 0.9632 - precision_2: 0.7368 - recall_2: 0.3981
# Epoch 25/50
# 338/338 [==============================] - 0s 509us/step - loss: 1.0134 - precision_2: 0.7185 - recall_2: 0.3413
# Epoch 26/50
# 338/338 [==============================] - 0s 559us/step - loss: 0.8678 - precision_2: 0.7704 - recall_2: 0.4254
# Epoch 27/50
# 338/338 [==============================] - 0s 509us/step - loss: 0.9322 - precision_2: 0.7258 - recall_2: 0.3613
# Epoch 28/50
# 338/338 [==============================] - 0s 503us/step - loss: 1.1011 - precision_2: 0.6671 - recall_2: 0.2785
# Epoch 29/50
# 338/338 [==============================] - 0s 559us/step - loss: 0.9254 - precision_2: 0.7285 - recall_2: 0.3985
# Epoch 30/50
# 338/338 [==============================] - 0s 512us/step - loss: 0.9093 - precision_2: 0.7459 - recall_2: 0.4164
# Epoch 31/50
# 338/338 [==============================] - 0s 527us/step - loss: 0.9147 - precision_2: 0.7655 - recall_2: 0.3793

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='acc',mode='max', patience=5)
Adam = tf.optimizers.Adam(lr=0.003, beta_1=0.9, beta_2=0.997, epsilon=1e-08, decay=0.0)
model.compile(optimizer=Adam, 
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics = [tf.keras.metrics.Precision(),tf.keras.metrics.Recall(),tf.keras.metrics.Accuracy()]
              )
history = model.fit(x=x_train, y=y_train,  epochs=50,batch_size =5, callbacks=[callback] )
# Out:
# Epoch 1/50
# 338/338 [==============================] - 1s 530us/step - loss: 0.9497 - precision_3: 0.7249 - recall_3: 0.3887 - accuracy: 0.1023
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 2/50
# 338/338 [==============================] - 0s 521us/step - loss: 0.8501 - precision_3: 0.7686 - recall_3: 0.4478 - accuracy: 0.1176
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 3/50
# 338/338 [==============================] - 0s 539us/step - loss: 0.9311 - precision_3: 0.7499 - recall_3: 0.4041 - accuracy: 0.1417
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 4/50
# 338/338 [==============================] - 0s 550us/step - loss: 0.8872 - precision_3: 0.7926 - recall_3: 0.4402 - accuracy: 0.1411
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 5/50
# 338/338 [==============================] - 0s 553us/step - loss: 1.0472 - precision_3: 0.6324 - recall_3: 0.3176 - accuracy: 0.0838
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 31/50
# 338/338 [==============================] - 0s 540us/step - loss: 0.8579 - precision_3: 0.7530 - recall_3: 0.4999 - accuracy: 0.2016
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 32/50
# 338/338 [==============================] - 0s 613us/step - loss: 1.0413 - precision_3: 0.6667 - recall_3: 0.3061 - accuracy: 0.1023
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 33/50
# 338/338 [==============================] - 0s 552us/step - loss: 0.9540 - precision_3: 0.7013 - recall_3: 0.3780 - accuracy: 0.1124
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 34/50
# 338/338 [==============================] - 0s 559us/step - loss: 1.0600 - precision_3: 0.6339 - recall_3: 0.3459 - accuracy: 0.1142
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 35/50
# 338/338 [==============================] - 0s 533us/step - loss: 0.9851 - precision_3: 0.7027 - recall_3: 0.3698 - accuracy: 0.1185
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 36/50
# 338/338 [==============================] - 0s 553us/step - loss: 1.0065 - precision_3: 0.6600 - recall_3: 0.3286 - accuracy: 0.1093
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 37/50
# 338/338 [==============================] - 0s 556us/step - loss: 0.9616 - precision_3: 0.7181 - recall_3: 0.3843 - accuracy: 0.1146
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 38/50
# 338/338 [==============================] - 0s 545us/step - loss: 0.9932 - precision_3: 0.6795 - recall_3: 0.3463 - accuracy: 0.1174
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 39/50
# 338/338 [==============================] - 0s 530us/step - loss: 0.9334 - precision_3: 0.7691 - recall_3: 0.4381 - accuracy: 0.1687
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 40/50
# 338/338 [==============================] - 0s 541us/step - loss: 0.9680 - precision_3: 0.7533 - recall_3: 0.4056 - accuracy: 0.1370
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 41/50
# 338/338 [==============================] - 0s 589us/step - loss: 0.9777 - precision_3: 0.7395 - recall_3: 0.4450 - accuracy: 0.1584
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 42/50
# 338/338 [==============================] - 0s 553us/step - loss: 0.8236 - precision_3: 0.8096 - recall_3: 0.4875 - accuracy: 0.1640
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 43/50
# 338/338 [==============================] - 0s 521us/step - loss: 0.8531 - precision_3: 0.7838 - recall_3: 0.4714 - accuracy: 0.1788
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 44/50
# 338/338 [==============================] - 0s 568us/step - loss: 1.0022 - precision_3: 0.6537 - recall_3: 0.3698 - accuracy: 0.1286
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 45/50
# 338/338 [==============================] - 0s 592us/step - loss: 0.8662 - precision_3: 0.7646 - recall_3: 0.4445 - accuracy: 0.1757
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 46/50
# 338/338 [==============================] - 0s 561us/step - loss: 0.8054 - precision_3: 0.7880 - recall_3: 0.4865 - accuracy: 0.2038
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 47/50
# 338/338 [==============================] - 0s 610us/step - loss: 0.8315 - precision_3: 0.8063 - recall_3: 0.5196 - accuracy: 0.2091
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 48/50
# 338/338 [==============================] - 0s 599us/step - loss: 0.8385 - precision_3: 0.7739 - recall_3: 0.4784 - accuracy: 0.2038
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 49/50
# 338/338 [==============================] - 0s 536us/step - loss: 1.0964 - precision_3: 0.6560 - recall_3: 0.3746 - accuracy: 0.1519
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy
# Epoch 50/50
# 338/338 [==============================] - 0s 527us/step - loss: 0.8174 - precision_3: 0.7473 - recall_3: 0.4864 - accuracy: 0.1652
# WARNING:tensorflow:Early stopping conditioned on metric `acc` which is not available. Available metrics are: loss,precision_3,recall_3,accuracy

# %%
preds = model.evaluate(x = x_test, y = y_test)

F1 = 2 * (preds[1] * preds[2]) / (preds[1] + preds[2])
print(preds)
print(F1)
# Out:
# 14/14 [==============================] - 0s 614us/step - loss: 0.5759 - precision_3: 0.8606 - recall_3: 0.6714 - accuracy: 0.2644
# [0.5758947134017944, 0.8606060743331909, 0.6713948249816895, 0.2644376754760742]
# 0.7543160906935628

# %%
pd.DataFrame(history.history).plot(figsize = (8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 2.5)
plt.show()

# %% [markdown]
# # value
